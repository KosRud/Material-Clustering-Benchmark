// %% [markdown]
// # Setup

// %% [markdown]
// ## Imports

// %%
import Plotly from "tslab-plotly";
import * as tslab from "tslab";

// %% [markdown]
// ## Shared layout

// %%
const sharedLayout = {
    width: 600,
    height: 400,
    font: {
        size: 15,
    },
    yaxis: {
        automargin: true,
    },
    xaxis: {
        automargin: true,
    },
    margin: {
        l: 4,
        r: 4,
        b: 4,
        t: 50, // for title
        pad: 0, // between axis and plot
    },
};

// %% [markdown]
// # Plotly demo

// %%
(() => {
    let trace1: Plotly.Data = {
        x: ['giraffes', 'orangutans', 'monkeys'],
        y: [20, 14, 23],
        name: 'Zoo 1',
        type: 'bar',
    };

    let trace2: Plotly.Data = {
        x: ['giraffes', 'orangutans', 'monkeys'],
        y: [12, 18, 29],
        name: 'Zoo 2',
        type: 'bar',
    };

    let trace3: Plotly.Data = {
        x: ['penguins', 'crocodiles', 'swans'],
        y: [16, 10, 28],
        name: 'Zoo 3',
        type: 'bar',

        xaxis: 'x2',
        yaxis: 'y2',
    };

    let trace4: Plotly.Data = {
        x: ['penguins', 'crocodiles', 'swans'],
        y: [24, 12, 16],
        name: 'Zoo 4',
        type: 'bar',

        xaxis: 'x2',
        yaxis: 'y2',
    };

    let data: Plotly.Data[] = [trace1, trace2, trace3, trace4];
    let layout: Partial<Plotly.Layout> = {
        ...sharedLayout,

        grid: { rows: 1, columns: 2, pattern: 'independent' },
        title: 'Animals in different zoos',
        barmode: 'group',
        annotations: [
            // subplot titles (hack)
            {
                text: 'First subplot',
                font: {
                    size: 16,
                },
                align: 'center',
                x: 0.13, //position in x domain
                y: 1.1, //position in y domain
                xref: 'paper',
                yref: 'paper',
                showarrow: false,
            },
            {
                text: 'Second subplot',
                font: {
                    size: 16,
                },
                align: 'center',
                x: 0.9, //position in x domain
                y: 1.1, // position in y domain
                xref: 'paper',
                yref: 'paper',
                showarrow: false,
            },
        ],
    };
    Plotly.newPlot(tslab, data, layout);
})();
// Out:
//       <div
//         id="_plotly-davxyzbaf3q5"
//         style="width:600px;height:400px;">
//       </div>
//       <script>
//       {
//         function ensurePlotly() {
//     if (!window.PlotlyPromise) {
//         const define = window.define;
//         window.define = undefined; // avoid plotly thinking it is in a requirejs environment (vscode)
//         const script = document.createElement("script");
//         script.setAttribute("type", "text/javascript");
//         script.setAttribute("id", "plotly-lib-bundle");
//         script.setAttribute("src", "https://cdn.plot.ly/plotly-latest.min.js");
//         window.PlotlyPromise = new Promise((resolve, reject) => {
//             script.onload = () => resolve();
//             script.onerror = () => reject(new Error("Error loading " + script.getAttribute("src")));
//         });
//         document.head.appendChild(script);
//         window.PlotlyPromise.catch().then(() => {
//             window.define = define;
//         });
//     }
// }
//         async function runPlotlyScript(plotId, data, layout, config) {
//     const plotContainer = document.getElementById(plotId);
//     try {
//         await window.PlotlyPromise;
//         window.Plotly.newPlot(plotContainer, data, layout, config);
//     }
//     catch (e) {
//         plotContainer.innerText = e.message + "\\n" + e.stack;
//     }
// }
//
//         ensurePlotly();
//         runPlotlyScript(...["_plotly-davxyzbaf3q5",[{"x":["giraffes","orangutans","monkeys"],"y":[20,14,23],"name":"Zoo 1","type":"bar"},{"x":["giraffes","orangutans","monkeys"],"y":[12,18,29],"name":"Zoo 2","type":"bar"},{"x":["penguins","crocodiles","swans"],"y":[16,10,28],"name":"Zoo 3","type":"bar","xaxis":"x2","yaxis":"y2"},{"x":["penguins","crocodiles","swans"],"y":[24,12,16],"name":"Zoo 4","type":"bar","xaxis":"x2","yaxis":"y2"}],{"margin":{"l":4,"r":4,"b":4,"t":50,"pad":0},"width":600,"height":400,"font":{"size":15},"yaxis":{"automargin":true},"xaxis":{"automargin":true},"grid":{"rows":1,"columns":2,"pattern":"independent"},"title":"Animals in different zoos","barmode":"group","annotations":[{"text":"First subplot","font":{"size":16},"align":"center","x":0.13,"y":1.1,"xref":"paper","yref":"paper","showarrow":false},{"text":"Second subplot","font":{"size":16},"align":"center","x":0.9,"y":1.1,"xref":"paper","yref":"paper","showarrow":false}]},null]);
//       }
//       </script>

// %% [markdown]
// # Loading report collections

// %%
import fs from 'fs';
import unpackUnityJson from './util/unpackUnityJson';
import loadReportCollection from './util/loadReportCollection';
import path from 'path';

const reportCollections = (() => {
    const reportDir = './Reports/';
    const reportCollections = {};
    for (const reportFileName of fs.readdirSync(reportDir)) {
        const reportPath = path.join(reportDir, reportFileName);

        let reportName = reportFileName;
        const reportNameParts = reportFileName.split('.');
        reportNameParts.splice(-1, 1);
        reportName = reportNameParts.join('');

        reportCollections[reportName] = loadReportCollection(
            unpackUnityJson(JSON.parse(fs.readFileSync(reportPath, 'utf-8')))
        ).reports;
    }

    return reportCollections;
})();

// %%
(() => {
    const keys = Object.keys(reportCollections);
    console.dir(keys);
    console.dir({
        launchParameters: reportCollections[keys[0]][0].launchParameters,
    });
})();
// Out:
// [
//   'Empty cluster randomization',
//   'Random swap (1KM) vs Random swap (2KM)',
//   'Scaling vs subsampling',
//   'Scanline jitter',
//   'Staggered jitter',
//   'Subsampling'
// ]
// {
//   launchParameters: {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 8,
//     numClusters: 16,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   }
// }

// %% [markdown]
// # Plots
//
// ## Subsampling

// %%
(() => {
    const subsamplingReports = reportCollections['Subsampling'];

    const textureSizeOptions = Array.from(
        new Set(
            subsamplingReports.map(
                (report) => report.launchParameters.workingTextureSize
            )
        )
    );

    const videoNameOptions = Array.from(
        new Set(
            subsamplingReports.map(
                (report) => report.launchParameters.videoName
            )
        )
    ).sort();

    for (const aggregatedStatName of ['mean', 'peak']) {
        for (const videoName of videoNameOptions) {
            const subsetVideo = subsamplingReports.filter(
                (report) => report.launchParameters.videoName == videoName
            );

            const data: Plotly.Data[] = textureSizeOptions.map(
                (textureSize) => {
                    const subsetTextureSize = subsetVideo
                        .filter(
                            (report) =>
                                report.launchParameters.workingTextureSize ==
                                textureSize
                        );

                    return {
                        y: subsetTextureSize.map(
                            (report) =>
                                report.measurement.aggregated[
                                    aggregatedStatName
                                ]
                        ),

                        x: subsetTextureSize.map(
                            (report) => `${report.launchParameters.numClusters}`
                        ),

                        name: `${textureSize}`,
                        type: 'bar',
                    };
                }
            );

            // todo fix definitions Plotly.Layout
            const layout: any /*Partial<Plotly.Layout>*/ = {
                ...sharedLayout,

                xaxis: {
                    title: 'number of clusters',
                    type: 'category',
                },

                yaxis: {
                    title: {
                        text: `${aggregatedStatName} variance`,
                        standoff: 4,
                    },
                    automargin: true,
                },

                legend: {
                    title: {
                        text: 'texture size',
                    },
                },

                margin: {
                    l: 80,
                    r: 4,
                    b: 40,
                    t: 50, // for title
                    pad: 0, // between axis and plot
                },

                title: `Subsampling (video ${videoName})`,
            };

            Plotly.newPlot(tslab, data, layout);
            tslab.display.html('<br>');
        }
    }
})();
// Out:
//       <div
//         id="_plotly-davjbbohf1li"
//         style="width:600px;height:400px;">
//       </div>
//       <script>
//       {
//         function ensurePlotly() {
//     if (!window.PlotlyPromise) {
//         const define = window.define;
//         window.define = undefined; // avoid plotly thinking it is in a requirejs environment (vscode)
//         const script = document.createElement("script");
//         script.setAttribute("type", "text/javascript");
//         script.setAttribute("id", "plotly-lib-bundle");
//         script.setAttribute("src", "https://cdn.plot.ly/plotly-latest.min.js");
//         window.PlotlyPromise = new Promise((resolve, reject) => {
//             script.onload = () => resolve();
//             script.onerror = () => reject(new Error("Error loading " + script.getAttribute("src")));
//         });
//         document.head.appendChild(script);
//         window.PlotlyPromise.catch().then(() => {
//             window.define = define;
//         });
//     }
// }
//         async function runPlotlyScript(plotId, data, layout, config) {
//     const plotContainer = document.getElementById(plotId);
//     try {
//         await window.PlotlyPromise;
//         window.Plotly.newPlot(plotContainer, data, layout, config);
//     }
//     catch (e) {
//         plotContainer.innerText = e.message + "\\n" + e.stack;
//     }
// }
//
//         ensurePlotly();
//         runPlotlyScript(...["_plotly-davjbbohf1li",[{"y":[0.0020312992459815674,0.0031747716512311474,0.006164471315678775,0.009368827735161959,0.01596860807050728],"x":["16","12","8","6","4"],"name":"8","type":"bar"},{"y":[0.0019996120466715585,0.003080531177806293,0.006235771950052504,0.00940395811541533,0.015693940113167784],"x":["16","12","8","6","4"],"name":"16","type":"bar"},{"y":[0.0017659191382856118,0.002820717231212472,0.005892975224280274,0.008853733172747857,0.016422696163347718],"x":["16","12","8","6","4"],"name":"32","type":"bar"},{"y":[0.0017646218428760015,0.0028059961068098464,0.005704988243148452,0.008746383237534813,0.016370002600572184],"x":["16","12","8","6","4"],"name":"64","type":"bar"},{"y":[0.0017528278298828731,0.002852558997767647,0.005727872053006043,0.008781064038104828,0.016802751931652267],"x":["16","12","8","6","4"],"name":"128","type":"bar"},{"y":[0.0018742349090915854,0.0030697095065292533,0.00617429290026907,0.009428707429918871,0.01803585543707814],"x":["16","12","8","6","4"],"name":"256","type":"bar"},{"y":[0.0018594777789242285,0.0030590603023677343,0.006192777913929995,0.00942175398675865,0.01803898219850355],"x":["16","12","8","6","4"],"name":"512","type":"bar"}],{"margin":{"l":80,"r":4,"b":40,"t":50,"pad":0},"width":600,"height":400,"font":{"size":15},"yaxis":{"title":{"text":"mean variance","standoff":4},"automargin":true},"xaxis":{"title":"number of clusters","type":"category"},"legend":{"title":{"text":"texture size"}},"title":"Subsampling (video 1)"},null]);
//       }
//       </script>
// <br>
//       <div
//         id="_plotly-davm012b6s9x"
//         style="width:600px;height:400px;">
//       </div>
//       <script>
//       {
//         function ensurePlotly() {
//     if (!window.PlotlyPromise) {
//         const define = window.define;
//         window.define = undefined; // avoid plotly thinking it is in a requirejs environment (vscode)
//         const script = document.createElement("script");
//         script.setAttribute("type", "text/javascript");
//         script.setAttribute("id", "plotly-lib-bundle");
//         script.setAttribute("src", "https://cdn.plot.ly/plotly-latest.min.js");
//         window.PlotlyPromise = new Promise((resolve, reject) => {
//             script.onload = () => resolve();
//             script.onerror = () => reject(new Error("Error loading " + script.getAttribute("src")));
//         });
//         document.head.appendChild(script);
//         window.PlotlyPromise.catch().then(() => {
//             window.define = define;
//         });
//     }
// }
//         async function runPlotlyScript(plotId, data, layout, config) {
//     const plotContainer = document.getElementById(plotId);
//     try {
//         await window.PlotlyPromise;
//         window.Plotly.newPlot(plotContainer, data, layout, config);
//     }
//     catch (e) {
//         plotContainer.innerText = e.message + "\\n" + e.stack;
//     }
// }
//
//         ensurePlotly();
//         runPlotlyScript(...["_plotly-davm012b6s9x",[{"y":[0.006283783689084885,0.009305268899192498,0.014902839579991677,0.02160265949170659,0.0319053366065759],"x":["16","12","8","6","4"],"name":"8","type":"bar"},{"y":[0.0074250701449175265,0.013150039425582008,0.017859584479019305,0.023383681744031038,0.0311720233086553],"x":["16","12","8","6","4"],"name":"16","type":"bar"},{"y":[0.00851213737494254,0.01302929461100166,0.017484899329105248,0.021878292288289684,0.029546184553959392],"x":["16","12","8","6","4"],"name":"32","type":"bar"},{"y":[0.008135793907427797,0.010574983135833464,0.014885603456801618,0.020613953275262248,0.027459387340603825],"x":["16","12","8","6","4"],"name":"64","type":"bar"},{"y":[0.005699218917869075,0.008680531000714836,0.012438574712650734,0.017414533505587314,0.024390424200879352],"x":["16","12","8","6","4"],"name":"128","type":"bar"},{"y":[0.004632616335031344,0.0067543872444221055,0.010073758574435487,0.014325240805221255,0.021522609713778364],"x":["16","12","8","6","4"],"name":"256","type":"bar"},{"y":[0.004560925631165446,0.00681770696012245,0.010089019744598773,0.014326937672594795,0.021561335261329077],"x":["16","12","8","6","4"],"name":"512","type":"bar"}],{"margin":{"l":80,"r":4,"b":40,"t":50,"pad":0},"width":600,"height":400,"font":{"size":15},"yaxis":{"title":{"text":"mean variance","standoff":4},"automargin":true},"xaxis":{"title":"number of clusters","type":"category"},"legend":{"title":{"text":"texture size"}},"title":"Subsampling (video 2)"},null]);
//       }
//       </script>
// <br>
//       <div
//         id="_plotly-davj3ecwl3dp"
//         style="width:600px;height:400px;">
//       </div>
//       <script>
//       {
//         function ensurePlotly() {
//     if (!window.PlotlyPromise) {
//         const define = window.define;
//         window.define = undefined; // avoid plotly thinking it is in a requirejs environment (vscode)
//         const script = document.createElement("script");
//         script.setAttribute("type", "text/javascript");
//         script.setAttribute("id", "plotly-lib-bundle");
//         script.setAttribute("src", "https://cdn.plot.ly/plotly-latest.min.js");
//         window.PlotlyPromise = new Promise((resolve, reject) => {
//             script.onload = () => resolve();
//             script.onerror = () => reject(new Error("Error loading " + script.getAttribute("src")));
//         });
//         document.head.appendChild(script);
//         window.PlotlyPromise.catch().then(() => {
//             window.define = define;
//         });
//     }
// }
//         async function runPlotlyScript(plotId, data, layout, config) {
//     const plotContainer = document.getElementById(plotId);
//     try {
//         await window.PlotlyPromise;
//         window.Plotly.newPlot(plotContainer, data, layout, config);
//     }
//     catch (e) {
//         plotContainer.innerText = e.message + "\\n" + e.stack;
//     }
// }
//
//         ensurePlotly();
//         runPlotlyScript(...["_plotly-davj3ecwl3dp",[{"y":[0.03417022153735161,0.05981755256652832,0.07745400816202164,0.17322532832622528,0.22398492693901062],"x":["16","12","8","6","4"],"name":"8","type":"bar"},{"y":[0.019773637875914574,0.03304664418101311,0.06282628327608109,0.11756192147731781,0.12212013453245163],"x":["16","12","8","6","4"],"name":"16","type":"bar"},{"y":[0.013056294061243534,0.017734942957758904,0.03534679114818573,0.04648395627737045,0.14926131069660187],"x":["16","12","8","6","4"],"name":"32","type":"bar"},{"y":[0.009896662086248398,0.01393011026084423,0.02128864824771881,0.048488397151231766,0.08069603890180588],"x":["16","12","8","6","4"],"name":"64","type":"bar"},{"y":[0.007535732816904783,0.01014785747975111,0.014859018847346306,0.030744850635528564,0.0555257573723793],"x":["16","12","8","6","4"],"name":"128","type":"bar"},{"y":[0.00876427348703146,0.011574674397706985,0.014232645742595196,0.02145063690841198,0.0365046001970768],"x":["16","12","8","6","4"],"name":"256","type":"bar"},{"y":[0.006925302557647228,0.011392449028789997,0.014259827323257923,0.021453233435750008,0.03651195764541626],"x":["16","12","8","6","4"],"name":"512","type":"bar"}],{"margin":{"l":80,"r":4,"b":40,"t":50,"pad":0},"width":600,"height":400,"font":{"size":15},"yaxis":{"title":{"text":"peak variance","standoff":4},"automargin":true},"xaxis":{"title":"number of clusters","type":"category"},"legend":{"title":{"text":"texture size"}},"title":"Subsampling (video 1)"},null]);
//       }
//       </script>
// <br>
//       <div
//         id="_plotly-davfl9tpxi8y"
//         style="width:600px;height:400px;">
//       </div>
//       <script>
//       {
//         function ensurePlotly() {
//     if (!window.PlotlyPromise) {
//         const define = window.define;
//         window.define = undefined; // avoid plotly thinking it is in a requirejs environment (vscode)
//         const script = document.createElement("script");
//         script.setAttribute("type", "text/javascript");
//         script.setAttribute("id", "plotly-lib-bundle");
//         script.setAttribute("src", "https://cdn.plot.ly/plotly-latest.min.js");
//         window.PlotlyPromise = new Promise((resolve, reject) => {
//             script.onload = () => resolve();
//             script.onerror = () => reject(new Error("Error loading " + script.getAttribute("src")));
//         });
//         document.head.appendChild(script);
//         window.PlotlyPromise.catch().then(() => {
//             window.define = define;
//         });
//     }
// }
//         async function runPlotlyScript(plotId, data, layout, config) {
//     const plotContainer = document.getElementById(plotId);
//     try {
//         await window.PlotlyPromise;
//         window.Plotly.newPlot(plotContainer, data, layout, config);
//     }
//     catch (e) {
//         plotContainer.innerText = e.message + "\\n" + e.stack;
//     }
// }
//
//         ensurePlotly();
//         runPlotlyScript(...["_plotly-davfl9tpxi8y",[{"y":[0.10790553689002991,0.17667798697948456,0.24855180084705353,0.3588138520717621,0.39407795667648315],"x":["16","12","8","6","4"],"name":"8","type":"bar"},{"y":[0.12545908987522125,0.18040557205677032,0.20489701628684998,0.3211577236652374,0.38013455271720886],"x":["16","12","8","6","4"],"name":"16","type":"bar"},{"y":[0.1075572520494461,0.19104841351509094,0.22509391605854034,0.270500510931015,0.29613161087036133],"x":["16","12","8","6","4"],"name":"32","type":"bar"},{"y":[0.09002988785505295,0.10959077626466751,0.1309211254119873,0.2697943150997162,0.2784808278083801],"x":["16","12","8","6","4"],"name":"64","type":"bar"},{"y":[0.044554002583026886,0.05738593265414238,0.06454703211784363,0.15835009515285492,0.16824449598789215],"x":["16","12","8","6","4"],"name":"128","type":"bar"},{"y":[0.0199156254529953,0.026884028688073158,0.03339279070496559,0.05489160120487213,0.1113094836473465],"x":["16","12","8","6","4"],"name":"256","type":"bar"},{"y":[0.024423809722065926,0.026438431814312935,0.033410415053367615,0.05560023710131645,0.11434057354927063],"x":["16","12","8","6","4"],"name":"512","type":"bar"}],{"margin":{"l":80,"r":4,"b":40,"t":50,"pad":0},"width":600,"height":400,"font":{"size":15},"yaxis":{"title":{"text":"peak variance","standoff":4},"automargin":true},"xaxis":{"title":"number of clusters","type":"category"},"legend":{"title":{"text":"texture size"}},"title":"Subsampling (video 2)"},null]);
//       }
//       </script>
// <br>

// %% [markdown]
// ## Subsample vs Downscale

// %%
(() => {
    const downscalingReports = reportCollections['Scaling vs subsampling'];

    const doDownscaleOptions = Array.from(
        new Set(
            downscalingReports.map(
                (report) => report.launchParameters.doDownscale
            )
        )
    );

    const videoNameOptions = Array.from(
        new Set(
            downscalingReports.map(
                (report) => report.launchParameters.videoName
            )
        )
    ).sort();

    for (const aggregatedStatName of ['mean', 'peak']) {
        for (const videoName of videoNameOptions) {
            const subsetVideo = downscalingReports.filter(
                (report) => report.launchParameters.videoName == videoName
            );

            const data: Plotly.Data[] = doDownscaleOptions.map(
                (doDownscale) => {
                    const subsetDoDownscale = subsetVideo.filter(
                        (report) =>
                            report.launchParameters.doDownscale == doDownscale
                    );

                    return {
                        y: subsetDoDownscale.map(
                            (report) =>
                                report.measurement.aggregated[
                                    aggregatedStatName
                                ]
                        ),

                        x: subsetDoDownscale.map(
                            (report) =>
                                `${report.launchParameters.workingTextureSize}`
                        ),

                        name: `${doDownscale ? 'downscale' : 'subsample'}`,
                        type: 'bar',
                    };
                }
            );

            // todo fix definitions Plotly.Layout
            const layout: any /*Partial<Plotly.Layout>*/ = {
                ...sharedLayout,

                xaxis: {
                    title: 'working texture size',
                    type: 'category',
                },

                yaxis: {
                    title: {
                        text: `${aggregatedStatName} variance`,
                        standoff: 4,
                    },
                    automargin: true,
                },

                margin: {
                    l: 80,
                    r: 4,
                    b: 40,
                    t: 50, // for title
                    pad: 0, // between axis and plot
                },

                title: `Downscaling vs subsampling (video ${videoName})`,
            };

            Plotly.newPlot(tslab, data, layout);
            tslab.display.html('<br>');
        }
    }
})();
// Out:
// [
//   {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 8,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 8,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: true,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 16,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 16,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: true,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 32,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 32,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: true,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 64,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 64,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: true,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 128,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 128,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: true,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 256,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '2',
//     numIterations: 3,
//     workingTextureSize: 256,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: true,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '1',
//     numIterations: 3,
//     workingTextureSize: 8,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '1',
//     numIterations: 3,
//     workingTextureSize: 8,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: true,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '1',
//     numIterations: 3,
//     workingTextureSize: 16,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '1',
//     numIterations: 3,
//     workingTextureSize: 16,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: true,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '1',
//     numIterations: 3,
//     workingTextureSize: 32,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '1',
//     numIterations: 3,
//     workingTextureSize: 32,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: true,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '1',
//     numIterations: 3,
//     workingTextureSize: 64,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '1',
//     numIterations: 3,
//     workingTextureSize: 64,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: true,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '1',
//     numIterations: 3,
//     workingTextureSize: 128,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '1',
//     numIterations: 3,
//     workingTextureSize: 128,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: true,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '1',
//     numIterations: 3,
//     workingTextureSize: 256,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: false,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   },
//   {
//     dispatcherParameters: {},
//     videoName: '1',
//     numIterations: 3,
//     workingTextureSize: 256,
//     numClusters: 6,
//     jitterSize: 1,
//     staggeredJitter: false,
//     doDownscale: true,
//     algorithm: 'KM',
//     doRandomizeEmptyClusters: false
//   }
// ]
//       <div
//         id="_plotly-davn0e657qc7"
//         style="width:600px;height:400px;">
//       </div>
//       <script>
//       {
//         function ensurePlotly() {
//     if (!window.PlotlyPromise) {
//         const define = window.define;
//         window.define = undefined; // avoid plotly thinking it is in a requirejs environment (vscode)
//         const script = document.createElement("script");
//         script.setAttribute("type", "text/javascript");
//         script.setAttribute("id", "plotly-lib-bundle");
//         script.setAttribute("src", "https://cdn.plot.ly/plotly-latest.min.js");
//         window.PlotlyPromise = new Promise((resolve, reject) => {
//             script.onload = () => resolve();
//             script.onerror = () => reject(new Error("Error loading " + script.getAttribute("src")));
//         });
//         document.head.appendChild(script);
//         window.PlotlyPromise.catch().then(() => {
//             window.define = define;
//         });
//     }
// }
//         async function runPlotlyScript(plotId, data, layout, config) {
//     const plotContainer = document.getElementById(plotId);
//     try {
//         await window.PlotlyPromise;
//         window.Plotly.newPlot(plotContainer, data, layout, config);
//     }
//     catch (e) {
//         plotContainer.innerText = e.message + "\\n" + e.stack;
//     }
// }
//
//         ensurePlotly();
//         runPlotlyScript(...["_plotly-davn0e657qc7",[{"y":[0.009371569685816173,0.00940395811541533,0.008853733172747857,0.008746383237534813,0.008781064038104828,0.009428707429918871],"x":["8","16","32","64","128","256"],"name":"subsample","type":"bar"},{"y":[0.010662891283473757,0.009340155673870408,0.009098411041275305,0.008682179402282102,0.008713415212333403,0.009497766719219746],"x":["8","16","32","64","128","256"],"name":"downscale","type":"bar"}],{"margin":{"l":80,"r":4,"b":40,"t":50,"pad":0},"width":600,"height":400,"font":{"size":15},"yaxis":{"title":{"text":"mean variance","standoff":4},"automargin":true},"xaxis":{"title":"working texture size","type":"category"},"title":"Downscaling vs subsampling (video 1)"},null]);
//       }
//       </script>
// <br>
//       <div
//         id="_plotly-davihui5dynt"
//         style="width:600px;height:400px;">
//       </div>
//       <script>
//       {
//         function ensurePlotly() {
//     if (!window.PlotlyPromise) {
//         const define = window.define;
//         window.define = undefined; // avoid plotly thinking it is in a requirejs environment (vscode)
//         const script = document.createElement("script");
//         script.setAttribute("type", "text/javascript");
//         script.setAttribute("id", "plotly-lib-bundle");
//         script.setAttribute("src", "https://cdn.plot.ly/plotly-latest.min.js");
//         window.PlotlyPromise = new Promise((resolve, reject) => {
//             script.onload = () => resolve();
//             script.onerror = () => reject(new Error("Error loading " + script.getAttribute("src")));
//         });
//         document.head.appendChild(script);
//         window.PlotlyPromise.catch().then(() => {
//             window.define = define;
//         });
//     }
// }
//         async function runPlotlyScript(plotId, data, layout, config) {
//     const plotContainer = document.getElementById(plotId);
//     try {
//         await window.PlotlyPromise;
//         window.Plotly.newPlot(plotContainer, data, layout, config);
//     }
//     catch (e) {
//         plotContainer.innerText = e.message + "\\n" + e.stack;
//     }
// }
//
//         ensurePlotly();
//         runPlotlyScript(...["_plotly-davihui5dynt",[{"y":[0.021602261511027763,0.023383681744031038,0.021878292288289684,0.020613953275262248,0.017414533505587314,0.014325240805221255],"x":["8","16","32","64","128","256"],"name":"subsample","type":"bar"},{"y":[0.020270216503694313,0.022185235363717085,0.021951304612879086,0.020008812749848403,0.016934344938243157,0.014390933082002448],"x":["8","16","32","64","128","256"],"name":"downscale","type":"bar"}],{"margin":{"l":80,"r":4,"b":40,"t":50,"pad":0},"width":600,"height":400,"font":{"size":15},"yaxis":{"title":{"text":"mean variance","standoff":4},"automargin":true},"xaxis":{"title":"working texture size","type":"category"},"title":"Downscaling vs subsampling (video 2)"},null]);
//       }
//       </script>
// <br>
//       <div
//         id="_plotly-davon8bsx0rm"
//         style="width:600px;height:400px;">
//       </div>
//       <script>
//       {
//         function ensurePlotly() {
//     if (!window.PlotlyPromise) {
//         const define = window.define;
//         window.define = undefined; // avoid plotly thinking it is in a requirejs environment (vscode)
//         const script = document.createElement("script");
//         script.setAttribute("type", "text/javascript");
//         script.setAttribute("id", "plotly-lib-bundle");
//         script.setAttribute("src", "https://cdn.plot.ly/plotly-latest.min.js");
//         window.PlotlyPromise = new Promise((resolve, reject) => {
//             script.onload = () => resolve();
//             script.onerror = () => reject(new Error("Error loading " + script.getAttribute("src")));
//         });
//         document.head.appendChild(script);
//         window.PlotlyPromise.catch().then(() => {
//             window.define = define;
//         });
//     }
// }
//         async function runPlotlyScript(plotId, data, layout, config) {
//     const plotContainer = document.getElementById(plotId);
//     try {
//         await window.PlotlyPromise;
//         window.Plotly.newPlot(plotContainer, data, layout, config);
//     }
//     catch (e) {
//         plotContainer.innerText = e.message + "\\n" + e.stack;
//     }
// }
//
//         ensurePlotly();
//         runPlotlyScript(...["_plotly-davon8bsx0rm",[{"y":[0.17322532832622528,0.11756192147731781,0.04648395627737045,0.048488397151231766,0.030744850635528564,0.02145063690841198],"x":["8","16","32","64","128","256"],"name":"subsample","type":"bar"},{"y":[0.1839066594839096,0.11790572851896286,0.08685658872127533,0.04526320844888687,0.030132267624139786,0.021449288353323936],"x":["8","16","32","64","128","256"],"name":"downscale","type":"bar"}],{"margin":{"l":80,"r":4,"b":40,"t":50,"pad":0},"width":600,"height":400,"font":{"size":15},"yaxis":{"title":{"text":"peak variance","standoff":4},"automargin":true},"xaxis":{"title":"working texture size","type":"category"},"title":"Downscaling vs subsampling (video 1)"},null]);
//       }
//       </script>
// <br>
//       <div
//         id="_plotly-davtnrcdffw4"
//         style="width:600px;height:400px;">
//       </div>
//       <script>
//       {
//         function ensurePlotly() {
//     if (!window.PlotlyPromise) {
//         const define = window.define;
//         window.define = undefined; // avoid plotly thinking it is in a requirejs environment (vscode)
//         const script = document.createElement("script");
//         script.setAttribute("type", "text/javascript");
//         script.setAttribute("id", "plotly-lib-bundle");
//         script.setAttribute("src", "https://cdn.plot.ly/plotly-latest.min.js");
//         window.PlotlyPromise = new Promise((resolve, reject) => {
//             script.onload = () => resolve();
//             script.onerror = () => reject(new Error("Error loading " + script.getAttribute("src")));
//         });
//         document.head.appendChild(script);
//         window.PlotlyPromise.catch().then(() => {
//             window.define = define;
//         });
//     }
// }
//         async function runPlotlyScript(plotId, data, layout, config) {
//     const plotContainer = document.getElementById(plotId);
//     try {
//         await window.PlotlyPromise;
//         window.Plotly.newPlot(plotContainer, data, layout, config);
//     }
//     catch (e) {
//         plotContainer.innerText = e.message + "\\n" + e.stack;
//     }
// }
//
//         ensurePlotly();
//         runPlotlyScript(...["_plotly-davtnrcdffw4",[{"y":[0.3588138520717621,0.3211577236652374,0.270500510931015,0.2697943150997162,0.15835009515285492,0.05489160120487213],"x":["8","16","32","64","128","256"],"name":"subsample","type":"bar"},{"y":[0.26629438996315,0.32389819622039795,0.27064770460128784,0.23617517948150635,0.15253736078739166,0.05673281475901604],"x":["8","16","32","64","128","256"],"name":"downscale","type":"bar"}],{"margin":{"l":80,"r":4,"b":40,"t":50,"pad":0},"width":600,"height":400,"font":{"size":15},"yaxis":{"title":{"text":"peak variance","standoff":4},"automargin":true},"xaxis":{"title":"working texture size","type":"category"},"title":"Downscaling vs subsampling (video 2)"},null]);
//       }
//       </script>
// <br>
